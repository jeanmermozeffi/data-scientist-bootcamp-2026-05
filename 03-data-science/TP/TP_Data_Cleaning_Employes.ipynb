# %% [markdown]
# # 🧹 TD — Nettoyage d'un fichier d'employés avec Pandas
#
# **Module Data Science — TD de synthèse du chapitre _Data Cleaning & Transformation with Pandas_**
#
# Fichier de données : `fiche_employes.csv` · Cycle à suivre :
#
# > **DIAGNOSTIQUER → NETTOYER → TRANSFORMER → ANALYSER → SAUVEGARDER**
#
# ### Consignes
#
# - Une cellule de code par question, exécutée (code **+** résultat).
#
# - Une cellule Markdown de justification chaque fois que l'énoncé le demande.
#
# - On ne modifie jamais `df_raw` : on travaille sur la copie `df`.
#
# - Uniquement des notions du chapitre Pandas (aucun ML, aucun graphique).

# %% [markdown]
# ## Partie 0 — Mise en place
#
# **Q0.1** Importer `pandas` (`pd`) et `numpy` (`np`).
#
# **Q0.2** Charger `fiche_employes.csv` dans `df_raw`.
#
# **Q0.3** Créer la copie de travail `df = df_raw.copy()` et justifier (cellule Markdown ci-dessous).

# %%
import pandas as pd
import numpy as np

# Le CSV est dans le même dossier que ce notebook :
df_raw = pd.read_csv("fiche_employes.csv")
df = df_raw.copy()
df.head()

# %% [markdown]
# **Q0.3 — Pourquoi une copie ?**
#
# _(votre réponse ici)_

# %% [markdown]
# ## Partie 1 — Diagnostic : comprendre les données
#
# **Q1.1** 5 premières et 5 dernières lignes.
#
# **Q1.2** Nombre de lignes et de colonnes (`.shape`).
#
# **Q1.3** Liste des colonnes + **lister les problèmes** dans les noms (cellule Markdown).
#
# **Q1.4** `df.info()` : type de chaque colonne, correct ou à corriger ?
#
# **Q1.5** `df.describe()` : une valeur suspecte pour `Salary` ? pour `Age` ?
#
# **Q1.6** Valeurs manquantes par colonne (`isna().sum()`).
#
# **Q1.7** Nombre de lignes entièrement dupliquées (`duplicated().sum()`).
#
# **Q1.8** `value_counts()` sur `Employment_Status`, `Gender`, `Department`. Cohérent ?
#
# **Q1.9** Rédiger un **plan de nettoyage** en 6–8 points (cellule Markdown).

# %%
# Q1.1

# %%
# Q1.2

# %%
# Q1.3

# %% [markdown]
# **Q1.3 — Problèmes repérés dans les noms de colonnes :**
#
# _(votre réponse ici)_

# %%
# Q1.4

# %%
# Q1.5

# %%
# Q1.6

# %%
# Q1.7

# %%
# Q1.8

# %% [markdown]
# **Q1.9 — Plan de nettoyage :**
#
# 1.
#
# 2.
#
# 3.
#
# 4.
#
# 5.
#
# 6.

# %% [markdown]
# ## Partie 2 — Traiter les doublons
#
# **Q2.1** Afficher les lignes en double (`df[df.duplicated()]`). Combien ?
#
# **Q2.2** Supprimer avec `drop_duplicates()`. Combien de lignes restantes ?
#
# **Q2.3** Réindexer avec `reset_index(drop=True)`.
#
# **Q2.4** Vérifier qu'il ne reste aucun doublon.

# %%
# Q2.1

# %%
# Q2.2

# %%
# Q2.3

# %%
# Q2.4

# %% [markdown]
# ## Partie 3 — Traiter les valeurs manquantes (`Email`)
#
# **Q3.1** Afficher les lignes où `Email` est manquant. Combien maintenant ?
#
# **Q3.2** Reconstruire l'email au format `prenom.nom@entreprise.ci` (minuscules) et compléter avec `fillna()`.
#
# &nbsp;&nbsp;&nbsp;&nbsp;💡 `df["Fist Name"].str.lower() + "." + df["Last Name"].str.lower() + "@entreprise.ci"`
#
# **Q3.3** Vérifier : plus aucune valeur manquante dans tout le DataFrame.
#
# **Q3.4** Justifier ce choix (vs `dropna()` / `fillna("inconnu")`).

# %%
# Q3.1

# %%
# Q3.2

# %%
# Q3.3

# %% [markdown]
# **Q3.4 — Justification :**
#
# _(votre réponse ici)_

# %% [markdown]
# ## Partie 4 — Renommer les colonnes
#
# **Q4.1** Renommer avec `df.rename(columns={...})` :
#
# | Actuel | Attendu |
# |--------|---------|
# | `Fist Name` | `first_name` |
# | `Last Name` | `last_name` |
# | `Djob_tilte` | `job_title` |
# | `Ville` | `city` |
# | `Join_Date` | `join_date` |
# | les autres | minuscules : `age`, `email`, `phone`, `address`, `salary`, `employment_status`, `gender`, `department` |
#
# **Q4.2** Afficher `df.columns` pour vérifier.

# %%
# Q4.1

# %%
# Q4.2

# %% [markdown]
# ## Partie 5 — Corriger les types de données
#
# **Q5.1** Afficher `join_date.head()` et son `dtype`. Pourquoi impossible de calculer une ancienneté ?
#
# **Q5.2** Convertir `join_date` en date (`pd.to_datetime`). Vérifier le `dtype`.
#
# **Q5.3** Créer `years_employed` = année courante − `join_date.dt.year`.
#
# **Q5.4** Afficher `df[["join_date", "years_employed"]].head()`.
#
# **Q5.5** Ancienneté minimale et maximale ?

# %%
# Q5.1

# %%
# Q5.2

# %%
# Q5.3

# %%
# Q5.4

# %%
# Q5.5

# %% [markdown]
# ## Partie 6 — Nettoyer les colonnes de texte
#
# **Q6.1** `address` : remplacer `"\n"` par une espace (`.str.replace`).
#
# **Q6.2** `job_title` : les valeurs sont des tuples-texte `('Chef de projet finance',)`. Extraire l'intitulé réel.
#
# &nbsp;&nbsp;&nbsp;&nbsp;💡 `df["job_title"].str.strip("(),'\"")` **ou** `df["job_title"].str.extract(r"\(['\"](.+?)['\"],?\)")`
#
# &nbsp;&nbsp;&nbsp;&nbsp;⚠️ certaines valeurs utilisent des guillemets **doubles** — testez sur `.head(20)`.
#
# **Q6.3** Vérifier avec `nunique()` / `value_counts()` : plus de parenthèses ni guillemets.
#
# **Q6.4** Uniformiser la casse de `first_name` et `last_name` (`.str.title()`).

# %%
# Q6.1

# %%
# Q6.2  (testez les deux méthodes avant de choisir)

# %%
# Q6.3

# %%
# Q6.4

# %% [markdown]
# ## Partie 7 — Traiter les valeurs aberrantes (`salary`)
#
# **Q7.1** 10 salaires les plus élevés (`sort_values(ascending=False).head(10)`).
#
# **Q7.2** Colonne `salary_zscore` = `(salary - moyenne) / écart-type`.
#
# **Q7.3** Colonne booléenne `is_outlier` = `|z| > 3`. Combien d'aberrations ?
#
# **Q7.4** Afficher les lignes aberrantes. À partir de quel salaire ?
#
# **Q7.5** Remplacer le salaire des aberrants par la moyenne des **non** aberrants (`~df["is_outlier"]`, puis `df.loc[...] = ...`).
#
# **Q7.6** Reconvertir `salary` en entier.
#
# **Q7.7** Supprimer `salary_zscore` et `is_outlier` (`df.drop(columns=...)`).
#
# **Q7.8** Ré-afficher `df["salary"].describe()`. Le `max` est-il réaliste ?
#
# **Q7.9** Justifier : inconvénient du remplacement par la moyenne + une autre stratégie.

# %%
# Q7.1

# %%
# Q7.2

# %%
# Q7.3

# %%
# Q7.4

# %%
# Q7.5
# astuce : df["salary"] = df["salary"].astype(float) avant l'affectation pour éviter un warning de type

# %%
# Q7.6

# %%
# Q7.7

# %%
# Q7.8

# %% [markdown]
# **Q7.9 — Justification :**
#
# _(votre réponse ici)_

# %% [markdown]
# ## Partie 8 — Transformer et analyser
#
# **Q8.1** `tranche_salaire` via `pd.cut(salary, bins=[0, 40000, 80000, 120000, np.inf], labels=["Bas","Moyen","Élevé","Très élevé"])`.
#
# **Q8.2** `seniorite` via `apply()` : `<3` → Junior, `3–5` → Confirmé, `>5` → Senior.
#
# **Q8.3** `gender_label` via `map({"M":"Homme","F":"Femme"})`.
#
# **Q8.4** Salaire moyen par **département** (arrondi, trié décroissant).
#
# **Q8.5** Par **ville** : effectif (`count`), salaire moyen, âge moyen (`.agg([...])`).
#
# **Q8.6** Répartition par `tranche_salaire` (`value_counts()`).
#
# **Q8.7** Département avec l'ancienneté moyenne la plus élevée ?

# %%
# Q8.1

# %%
# Q8.2
def seniorite(n):
    ...

# %%
# Q8.3

# %%
# Q8.4

# %%
# Q8.5

# %%
# Q8.6

# %%
# Q8.7

# %% [markdown]
# ## Partie 9 — Contrôle qualité final & export
#
# **Q9.1** Ré-exécuter le diagnostic : `info()`, `isna().sum()`, `duplicated().sum()`, `dtypes`.
#
# **Q9.2** Tableau Markdown « Problème → Traitement appliqué ».
#
# **Q9.3** Exporter : `df.to_csv("fiche_employes_clean.csv", index=False, encoding="utf-8")`.
#
# **Q9.4** Recharger le fichier exporté et vérifier avec `.info()`.

# %%
# Q9.1

# %% [markdown]
# **Q9.2 — Récapitulatif :**
#
# | Problème | Traitement appliqué |
# |----------|---------------------|
# |  |  |
# |  |  |

# %%
# Q9.3

# %%
# Q9.4

# %% [markdown]
# ## 🎁 Bonus (facultatif — uniquement avec les `.str` du cours)
#
# **B1** Uniformiser `employment_status` (mélange `CDD`/`CDI` FR et `Full-Time`/`Part-Time` EN) avec `map()`/`replace()` + justification.
#
# **B2** `phone_clean` : ne garder que les chiffres (`.str.replace(r"\D", "", regex=True)`).
#
# **B3** Emails en doublon après nettoyage (`df["email"].duplicated().sum()`) : combien ? faut-il les traiter ?

# %%
# B1

# %%
# B2

# %%
# B3

# %% [markdown]
# **B1 / B3 — Justifications :**
#
# _(votre réponse ici)_
