# %%
# Créer un set depuis une liste (pour supprimer les doublons)
notes = [14, 16, 14, 18, 16, 12, 14]
notes_uniques = set(notes)
print(notes_uniques)  # {12, 14, 16, 18}  # 3

# %%
print(len(notes_uniques))

# %% [markdown]
# 6.2 Ajouter et supprimer

# %%
def saluer(prenom):     # "prenom" est un PARAMÈTRE
    print(f"Bonjour, {prenom} !")

# %%
saluer("Alice")
# Out:
# Bonjour, Alice !

# %%
def afficher_note(note):
    print(f"Votre note est : {note}/20")

# %%
afficher_note(17)
# Out:
# Votre note est : 17/20

# %%
afficher_note(10)
# Out:
# Votre note est : 10/20

# %%
def presenter(nom, age, ville):
  print(f"Je suis {nom}, j'ai {age} ans et j'habite à {ville}.")

# %%
presenter(ville="Paris", age=25, nom="Alice")
# Out:
# Je suis Alice, j'ai 25 ans et j'habite à Paris.

# %%
presenter("Claire", ville="Tanda", age=22)
# Out:
# Je suis Claire, j'ai 22 ans et j'habite à Tanda.

# %% [markdown]
# ### 4. Fonctions à plusieurs paramètres

# %% [markdown]
# #### 4.1 Exemple — Calcul d'une moyenne pondérée

# %%
def moyenne_ponderee(note_examen, note_projet, note_partiel):
     """Calcule une moyenne pondérée : 50% examen, 30% projet, 20% partiel."""
     total = (note_examen * 0.5) + (note_projet * 0.3) + (note_partiel * 0.2)
     return total

# %%
resutat = moyenne_ponderee(14, 10, 15)
print(f"Resut : {resutat}")
# Out:
# Resut : 13.0

# %% [markdown]
# ### 4.2 Exemple — Calcul du prix TTC

# %%
def prix_ttc(prix_ht, taux_tva=0.18, remise=0):
    """Calcule le prix TTC après application de la TVA et d'une remise."""
    prix_apres_remise = prix_ht - (prix_ht * remise)
    ttc = prix_apres_remise * (1 + taux_tva)
    return round(ttc, 2)

# %%
print(prix_ttc(10000, 0.18))
print(prix_ttc(10000, 0.18, 0.10))
# Out:
# 11800.0
# 10620.0

# %% [markdown]
# ### 4.3 Fonction avec logique conditionnelle

# %%
def evaluer_note(nom, note):
    """Retourne un message d'évaluation selon la note."""
    if note >= 16:
        mention = "Très bien 🏆"
    elif note >= 14:
        mention = "Bien 👍"
    elif note >= 10:
        mention = "Passable"
    else:
        mention = "Insuffisant ❌"

    return f"{nom} : {note}/20 — {mention}"

# %%
print(evaluer_note("Alice", 17))   # Alice : 17/20 — Très bien 🏆
# Out:
# Alice : 17/20 — Très bien 🏆

# %%
print(evaluer_note("Bob", 8))      # Bob : 8/20 — Insuffisant ❌
# Out:
# Bob : 8/20 — Insuffisant ❌

# %%
def statistiques(notes):
    """Retourne plusieurs statistiques en une seule fois."""
    minimum = min(notes)
    maximum = max(notes)
    moyenne = sum(notes) / len(notes)
    return minimum, maximum, moyenne

# %%
notes = [14, 18, 12, 16, 10]

# %%
mini, maxi, moy = statistiques(notes)
print(f"Min : {mini}, Max : {maxi}, Moyenne : {moy:.2f}")
# Out:
# Min : 10, Max : 18, Moyenne : 14.00

# %%
print((type(mini), type(maxi), type(moy)))
# Out:
# (<class 'int'>, <class 'int'>, <class 'float'>)
